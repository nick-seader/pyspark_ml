# %% [markdown]
# # Logistic Regression

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('mylogreg').getOrCreate()

# %%
from pyspark.ml.classification import LogisticRegression

# %%
my_data = spark.read.format('libsvm').load('/FileStore/tables/sample_libsvm_data.txt')

# %%
my_data.show()
# Out:
# +-----+--------------------+
# |label|            features|
# +-----+--------------------+
# |  0.0|(692,[127,128,129...|
# |  1.0|(692,[158,159,160...|
# |  1.0|(692,[124,125,126...|
# |  1.0|(692,[152,153,154...|
# |  1.0|(692,[151,152,153...|
# |  0.0|(692,[129,130,131...|
# |  1.0|(692,[158,159,160...|
# |  1.0|(692,[99,100,101,...|
# |  0.0|(692,[154,155,156...|
# |  0.0|(692,[127,128,129...|
# |  1.0|(692,[154,155,156...|
# |  0.0|(692,[153,154,155...|
# |  0.0|(692,[151,152,153...|
# |  1.0|(692,[129,130,131...|
# |  0.0|(692,[154,155,156...|
# |  1.0|(692,[150,151,152...|
# |  0.0|(692,[124,125,126...|
# |  0.0|(692,[152,153,154...|
# |  1.0|(692,[97,98,99,12...|
# |  1.0|(692,[124,125,126...|
# +-----+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Model

# %%
my_log_reg_model = LogisticRegression()

# %%
fitted_logreg_model = my_log_reg_model.fit(my_data)

# %%
log_summary = fitted_logreg_model.summary

# %%
log_summary.predictions.printSchema()
# Out:
# root
#  |-- label: double (nullable = true)
#  |-- features: vector (nullable = true)
#  |-- rawPrediction: vector (nullable = true)
#  |-- probability: vector (nullable = true)
#  |-- prediction: double (nullable = false)

# %%
log_summary.predictions.show()
# Out:
# +-----+--------------------+--------------------+--------------------+----------+
# |label|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+--------------------+--------------------+----------+
# |  0.0|(692,[127,128,129...|[20.3777627514872...|[0.99999999858729...|       0.0|
# |  1.0|(692,[158,159,160...|[-21.114014198868...|[6.76550380000486...|       1.0|
# |  1.0|(692,[124,125,126...|[-23.743613234676...|[4.87842678716171...|       1.0|
# |  1.0|(692,[152,153,154...|[-19.192574012720...|[4.62137287298141...|       1.0|
# |  1.0|(692,[151,152,153...|[-20.125398874699...|[1.81823629113070...|       1.0|
# |  0.0|(692,[129,130,131...|[20.4890549504196...|[0.99999999873608...|       0.0|
# |  1.0|(692,[158,159,160...|[-21.082940212814...|[6.97903542823781...|       1.0|
# |  1.0|(692,[99,100,101,...|[-19.622713503550...|[3.00582577446123...|       1.0|
# ...

# %% [markdown]
# # Split and Evaluate

# %%
lr_train, lr_test = my_data.randomSplit([0.7, 0.3])

# %%
final_model = LogisticRegression()

# %%
fit_final = final_model.fit(lr_train)

# %%
prediction_and_labels = fit_final.evaluate(lr_test)

# %%
prediction_and_labels.predictions.show()
# Out:
# +-----+--------------------+--------------------+--------------------+----------+
# |label|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+--------------------+--------------------+----------+
# |  0.0|(692,[100,101,102...|[0.75592114176372...|[0.68046751519791...|       0.0|
# |  0.0|(692,[122,123,148...|[12.1070874890487...|[0.99999447978091...|       0.0|
# |  0.0|(692,[123,124,125...|[29.0537899261354...|[0.99999999999975...|       0.0|
# |  0.0|(692,[126,127,128...|[24.7566695450418...|[0.99999999998228...|       0.0|
# |  0.0|(692,[127,128,129...|[19.6188139638453...|[0.99999999698243...|       0.0|
# |  0.0|(692,[153,154,155...|[29.9479670896341...|[0.99999999999990...|       0.0|
# |  0.0|(692,[153,154,155...|[22.8888276908526...|[0.99999999988531...|       0.0|
# |  0.0|(692,[153,154,155...|[7.93370061243173...|[0.99964167100232...|       0.0|
# ...

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator

# %%
my_eval = BinaryClassificationEvaluator()

# %%
roc_results = my_eval.evaluate(prediction_and_labels.predictions)

# %%
roc_results
# Out:
# Out[21]: 1.0

# %% [markdown]
# This 1.0 means a perfect fit. Always be suspicious.
