# %% [markdown]
# # Trees Project - Find the Faulty Preservative

# %% [markdown]
# Which feature is important to determine spoilage?

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('tree_consult').getOrCreate()

# %%
data = spark.read.csv('/FileStore/tables/dog_food.csv', inferSchema=True, header=True)

# %%
data.head(2)
# Out:
# Out[4]: [Row(A=4, B=2, C=12.0, D=3, Spoiled=1.0),
#  Row(A=5, B=6, C=12.0, D=7, Spoiled=1.0)]

# %% [markdown]
# # Process Data

# %%
from pyspark.ml.feature import VectorAssembler

# %%
assembler = VectorAssembler(
    inputCols=['A', 'B', 'C', 'D'],
    outputCol='features'
)

# %%
output = assembler.transform(data)

# %% [markdown]
# # Build Model

# %%
from pyspark.ml.classification import RandomForestClassifier

# %%
rfc = RandomForestClassifier(labelCol='Spoiled', featuresCol='features')

# %%
output.printSchema()
# Out:
# root
#  |-- A: integer (nullable = true)
#  |-- B: integer (nullable = true)
#  |-- C: double (nullable = true)
#  |-- D: integer (nullable = true)
#  |-- Spoiled: double (nullable = true)
#  |-- features: vector (nullable = true)

# %%
final_data = output.select(['features', 'Spoiled'])

# %%
final_data.show()
# Out:
# +-------------------+-------+
# |           features|Spoiled|
# +-------------------+-------+
# | [4.0,2.0,12.0,3.0]|    1.0|
# | [5.0,6.0,12.0,7.0]|    1.0|
# | [6.0,2.0,13.0,6.0]|    1.0|
# | [4.0,2.0,12.0,1.0]|    1.0|
# | [4.0,2.0,12.0,3.0]|    1.0|
# |[10.0,3.0,13.0,9.0]|    1.0|
# | [8.0,5.0,14.0,5.0]|    1.0|
# | [5.0,8.0,12.0,8.0]|    1.0|
# | [6.0,5.0,12.0,9.0]|    1.0|
# | [3.0,3.0,12.0,1.0]|    1.0|
# | [9.0,8.0,11.0,3.0]|    1.0|
# |[1.0,10.0,12.0,3.0]|    1.0|
# |[1.0,5.0,13.0,10.0]|    1.0|
# |[2.0,10.0,12.0,6.0]|    1.0|
# |[1.0,10.0,11.0,4.0]|    1.0|
# | [5.0,3.0,12.0,2.0]|    1.0|
# | [4.0,9.0,11.0,8.0]|    1.0|
# | [5.0,1.0,11.0,1.0]|    1.0|
# |[4.0,9.0,12.0,10.0]|    1.0|
# | [5.0,8.0,10.0,9.0]|    1.0|
# +-------------------+-------+
# only showing top 20 rows

# %%
rfc_model = rfc.fit(final_data)

# %%
final_data.head(1)
# Out:
# Out[16]: [Row(features=DenseVector([4.0, 2.0, 12.0, 3.0]), Spoiled=1.0)]

# %%
rfc_model.featureImportances
# Out:
# Out[17]: SparseVector(4, {0: 0.0189, 1: 0.0141, 2: 0.9384, 3: 0.0287})

# %% [markdown]
# # Result
#
# Preservative C is causing the spoilage!
